# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# data = pd.read_csv("csv/50_Startups.csv")
dataset = pd.read_csv("csv/multiple_linear_regression_dataset.csv")
dataset.head(5)
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
# sns.pairplot(dataset)
sns.heatmap(dataset.corr(), annot=True)
plt.show()

# %%
x = dataset.iloc[:, :-1]
y = dataset["income"]
lr = LinearRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=30)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9741881533363435

# %%
# q1 = dataset["experience"].quantile(0.25)
# q3 = dataset["experience"].quantile(0.75)
# iqr = q3 - q1
# mir = q1 - (1.5*iqr)
# mar = q3 + (1.5*iqr)
# new = dataset[(dataset["experience"]<mar)&( dataset["experience"] > mir)]
# sns.pairplot(data=new)

# # dataset.shape, new.shape
# # sns.boxplot(x="experience", data=new)
